# %%
import datetime
dt_now = datetime.datetime.now()
print(dt_now.strftime('%Y%m%d_%H%M'))
# Out:
# 20240513_1528

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import glob
import os
import numpy as np
import torch
import torch.optim as optim
import torchvision.transforms.functional as TF
from torchvision.transforms import v2
import torchvision.models as models
import torch.nn as nn
import cv2
from torch.utils.data import Dataset
from pathlib import Path
from typing import List, Tuple
from torch.utils.data import DataLoader
from torch.utils.data import random_split
import matplotlib.pyplot as plt
import datetime
import pandas as pd
import seaborn as sns; sns.set() # sns.set() ==> グラフの見た目をseabornに合わせる
# %matplotlib inline

time = datetime.datetime.now()
filedate=time.strftime('%Y%m%d_%H%M')

device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

Channels=3
batch_size=8
epochs=120
IMG_SIZE=224
valsplit=0.25

Classes = ["bread1", "bread2", "bread3"]
ClassNum = len(Classes)

trainpath=r".\Train"
savepath=r".\TrainedWeights"
historypath=r".\TrainHistory"

'''
PytorchではDataloaderという,膨大なデータセットからでもメモリを圧迫せずに取り出せてforループにも対応するための枠組みがある
データセットをDataloaderが引っ張ってこれるような形式にするためにMyDataset(torch.utils.data.Dataset)というクラスを作れば，
あとはそのメソッドをtorch.utils.data.Datasetが勝手に使用してデータを加工してくれる
__init__, __getitem__, __len__をクラス内で必ず定義しなければならない
Dataloader内のデータはバッチごとにまとめられる
'''
class MyDataset(Dataset):
    def __init__(self, root: str, transforms, Classes) -> None:
        super().__init__()
        self.transforms = transforms
        self.Classes = Classes
        #globは複数のファイルのパスをまとめて取得する
        #訓練と訓練白黒の二個下のディレクトリから画像を取得
        self.data = list(sorted(Path(root).glob("*\*")))


    # ここで取り出すデータを指定している
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        data = self.data[index]

        img1 = cv2.imread(str(data))
        img1 = cv2.resize(img1, (IMG_SIZE, IMG_SIZE))
        img1 = TF.to_tensor(img1)

        # データの変形 (transforms)
        transformed_img = self.transforms(img1)

        #ラベル貼り：dataというパスを/で区切ってリストにし，クラス名のところをラベルに格納
        #クラス名は文字列なので，self.Classesの要素と比較して一致するところの番号をラベルとする
        label = str(data).split("\\")[-2]
        label = torch.tensor(self.Classes.index(label))

        return transformed_img, label

    # この method がないと DataLoader を呼び出す際にエラーを吐かれる
    def __len__(self) -> int:
        return len(self.data)


#入力データに施す処理
transforms = v2.Compose([
        v2.ToDtype(torch.float32, scale=True),
        v2.Normalize(mean=[0,0,0], std=[0.2, 0.2, 0.2]),
])


trainvalset = MyDataset(root=trainpath, transforms=transforms, Classes=Classes)
trainset, valset = random_split(trainvalset, [1-valsplit, valsplit])

trainloader = DataLoader(dataset=trainset,batch_size=batch_size,shuffle=True)
valloader = DataLoader(dataset=valset,batch_size=batch_size,shuffle=True)


resnet50 = models.resnet50(weights='DEFAULT')


resnet50.conv1 = torch.nn.Conv2d(Channels,64,kernel_size = (7,7),stride = (2,2), padding = (3,3), bias = False)
num_ftrs = resnet50.fc.in_features
#modifying final layer
resnet50.fc = nn.Linear(num_ftrs,ClassNum)

#GPUにニューラルネットワークを渡す
resnet50=resnet50.to(device)

#lossfunction&optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(resnet50.parameters(), lr=0.001, momentum=0.9)

print("Device:", device, "IMGSIZE:(", Channels, IMG_SIZE, IMG_SIZE, ")",  "BatchSize:", batch_size, "Epochs:", epochs, "Valsplit:", valsplit, "Class:", Classes, "Final Layer Nodes:", num_ftrs)

'''
trainiterator
enumerateはtrainloader内のすべてのdataに対してループし，繰り返し回数をbatchに渡すという意味
Dataloader内ではバッチごとにデータがまとめられるので1回の取り出しで1バッチ分のデータを丸々取り出せる
'''
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []

def train(trainloader, valloader, model, loss_fn, optimizer, epochs):
    size = len(trainloader.dataset)
    num_batches = len(trainloader)
    size_val = len(valloader.dataset)
    num_batches_val = len(valloader)
    print("TrainData Size:", size, "TrainData Batches", num_batches, "ValData Size:", size_val, "ValData Batches:", num_batches_val)
    for epoch in range(epochs):
        running_loss, running_correct = 0, 0
        val_loss, val_correct = 0, 0
        for batch, (X, y) in enumerate(trainloader):
            X=X.to(device)
            y=y.to(device)
            # Compute prediction and loss
            pred = model(X)
            loss = loss_fn(pred, y)

            # Backpropagation
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            #損失と正解数の合計を計算しておき，後でそのエポック内での平均をとる
            running_loss += loss.item()
            running_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        epoch_loss = running_loss / num_batches
        epoch_acc = running_correct / size

        train_losses.append(epoch_loss)
        train_accuracies.append(epoch_acc)

        print(f'Epoch {epoch + 1} TrainLoss: {epoch_loss:.4f} TrainAcc: {epoch_acc:.4f}')

        # Set the model to evaluation mode - important for batch normalization and dropout layers
        model.eval()
        # Evaluating the model with torch.no_grad() ensures that no gradients are computed during test mode
        # also serves to reduce unnecessary gradient computations and memory usage for tensors with requires_grad=True
        with torch.no_grad():
            for X, y in valloader:
                X=X.to(device)
                y=y.to(device)
                pred = model(X)
                val_loss += loss_fn(pred, y).item()
                val_correct += (pred.argmax(1) == y).type(torch.float).sum().item()

            val_loss /= num_batches_val
            val_correct /= size_val
        # Set the model to train mode
        model.train()

        val_losses.append(val_loss)
        val_accuracies.append(val_correct)

        print(f'Epoch {epoch + 1} ValLoss: {val_loss:.4f} ValAcc: {val_correct:.4f}')

        #10epoch毎にパラメータを別々のフォルダに保存
        e1=epoch+1
        if (e1 % 10 == 0):
            savepathfolder=str(Path(savepath+"\\"+str(e1)))
            os.mkdir(savepathfolder)
            savepath2 = Path(savepathfolder+"\model_weights"+filedate+".pth")
            print('Saving Model...')
            torch.save(model.state_dict(), savepath2)
            print('Model saved in', savepath2)

        print(' ')

train(trainloader, valloader, resnet50, loss_fn, optimizer, epochs)

#グラフ可視化
#pltの(x,y)のxにあたるepochのリスト　1から開始
ep=np.arange(1, epochs+1)

#グラフにプロットする正解率と損失のリストをCSVに書き出し to_csvは新規フォルダを作ってくれないのでosで作る
historypath2 = str(Path(historypath+"\\"+filedate))
os.mkdir(historypath2)
pd.DataFrame(data=np.array([ep, train_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Train_Acc.csv"))
pd.DataFrame(data=np.array([ep, train_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Train_Loss.csv"))
pd.DataFrame(data=np.array([ep, val_accuracies]).T, columns=["Epoch", "Accuracy"]).to_csv(Path(historypath2+"\\"+"Val_Acc.csv"))
pd.DataFrame(data=np.array([ep, val_losses]).T, columns=["Epoch", "Loss"]).to_csv(Path(historypath2+"\\"+"Val_Loss.csv"))
print("CSVs saved in", historypath2)

def plot_acc(train_accuracies, val_accuracies):
    plt.plot(ep, train_accuracies)
    plt.plot(ep, val_accuracies)
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.yticks(np.arange(0.0, 1.05, 0.05))
    plt.legend(["train", "validation"], loc="lower right")
    plt.show()

def plot_loss(train_losses, val_losses):
    plt.plot(ep, train_losses)
    plt.plot(ep, val_losses)
    plt.title("model loss")
    plt.ylabel("loss")
    plt.xlabel("epoch")
    plt.xticks(np.arange(0, epochs+1, 10))
    plt.ylim(bottom=-5, top=10)
    plt.legend(["train", "validation"], loc="upper right")
    plt.show()

plot_acc(train_accuracies, val_accuracies)
plot_loss(train_losses, val_losses)

print('Training Finished!!!')
# Out:
# Device: cuda:0 IMGSIZE:( 3 224 224 ) BatchSize: 8 Epochs: 120 Valsplit: 0.25 Class: ['bread1', 'bread2', 'bread3'] Final Layer Nodes: 2048
# TrainData Size: 225 TrainData Batches 29 ValData Size: 75 ValData Batches: 10
# Epoch 1 TrainLoss: 0.9825 TrainAcc: 0.6578
# Epoch 1 ValLoss: 1.0953 ValAcc: 0.3600
#
# Epoch 2 TrainLoss: 0.5436 TrainAcc: 0.9200
# Epoch 2 ValLoss: 0.5224 ValAcc: 0.9200
#
# Epoch 3 TrainLoss: 0.1593 TrainAcc: 0.9956
# Epoch 3 ValLoss: 0.3516 ValAcc: 0.8800
#
# Epoch 4 TrainLoss: 0.0590 TrainAcc: 1.0000
# Epoch 4 ValLoss: 0.1357 ValAcc: 1.0000
#
# Epoch 5 TrainLoss: 0.0625 TrainAcc: 1.0000
# Epoch 5 ValLoss: 0.0838 ValAcc: 1.0000
#
# Epoch 6 TrainLoss: 0.0558 TrainAcc: 0.9956
# Epoch 6 ValLoss: 0.6124 ValAcc: 0.6267
#
# Epoch 7 TrainLoss: 0.0453 TrainAcc: 0.9956
# Epoch 7 ValLoss: 0.0629 ValAcc: 1.0000
#
# Epoch 8 TrainLoss: 0.0220 TrainAcc: 1.0000
# Epoch 8 ValLoss: 0.0275 ValAcc: 1.0000
#
# Epoch 9 TrainLoss: 0.0149 TrainAcc: 1.0000
# Epoch 9 ValLoss: 0.0178 ValAcc: 1.0000
#
# Epoch 10 TrainLoss: 0.0097 TrainAcc: 1.0000
# Epoch 10 ValLoss: 0.0065 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\10\model_weights20240513_1528.pth
#
# Epoch 11 TrainLoss: 0.0095 TrainAcc: 1.0000
# Epoch 11 ValLoss: 0.0059 ValAcc: 1.0000
#
# Epoch 12 TrainLoss: 0.0093 TrainAcc: 1.0000
# Epoch 12 ValLoss: 0.0025 ValAcc: 1.0000
#
# Epoch 13 TrainLoss: 0.0086 TrainAcc: 1.0000
# Epoch 13 ValLoss: 0.0029 ValAcc: 1.0000
#
# Epoch 14 TrainLoss: 0.0052 TrainAcc: 1.0000
# Epoch 14 ValLoss: 0.0031 ValAcc: 1.0000
#
# Epoch 15 TrainLoss: 0.0068 TrainAcc: 1.0000
# Epoch 15 ValLoss: 0.0020 ValAcc: 1.0000
#
# Epoch 16 TrainLoss: 0.0039 TrainAcc: 1.0000
# Epoch 16 ValLoss: 0.0014 ValAcc: 1.0000
#
# Epoch 17 TrainLoss: 0.0160 TrainAcc: 0.9956
# Epoch 17 ValLoss: 0.0016 ValAcc: 1.0000
#
# Epoch 18 TrainLoss: 0.0163 TrainAcc: 1.0000
# Epoch 18 ValLoss: 0.0044 ValAcc: 1.0000
#
# Epoch 19 TrainLoss: 0.0392 TrainAcc: 0.9956
# Epoch 19 ValLoss: 0.5279 ValAcc: 0.6800
#
# Epoch 20 TrainLoss: 0.0270 TrainAcc: 0.9956
# Epoch 20 ValLoss: 0.2424 ValAcc: 0.9067
# Saving Model...
# Model saved in TrainedWeights\20\model_weights20240513_1528.pth
#
# Epoch 21 TrainLoss: 0.0202 TrainAcc: 1.0000
# Epoch 21 ValLoss: 0.1291 ValAcc: 0.9600
#
# Epoch 22 TrainLoss: 0.0356 TrainAcc: 0.9956
# Epoch 22 ValLoss: 0.2134 ValAcc: 1.0000
#
# Epoch 23 TrainLoss: 0.0177 TrainAcc: 0.9956
# Epoch 23 ValLoss: 0.0395 ValAcc: 1.0000
#
# Epoch 24 TrainLoss: 0.0120 TrainAcc: 1.0000
# Epoch 24 ValLoss: 0.0043 ValAcc: 1.0000
#
# Epoch 25 TrainLoss: 0.0048 TrainAcc: 1.0000
# Epoch 25 ValLoss: 0.0154 ValAcc: 1.0000
#
# Epoch 26 TrainLoss: 0.0084 TrainAcc: 1.0000
# Epoch 26 ValLoss: 0.0015 ValAcc: 1.0000
#
# Epoch 27 TrainLoss: 0.0075 TrainAcc: 1.0000
# Epoch 27 ValLoss: 0.0049 ValAcc: 1.0000
#
# Epoch 28 TrainLoss: 0.0086 TrainAcc: 1.0000
# Epoch 28 ValLoss: 0.1519 ValAcc: 0.9467
#
# Epoch 29 TrainLoss: 0.0064 TrainAcc: 1.0000
# Epoch 29 ValLoss: 0.0012 ValAcc: 1.0000
#
# Epoch 30 TrainLoss: 0.0064 TrainAcc: 1.0000
# Epoch 30 ValLoss: 0.0009 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\30\model_weights20240513_1528.pth
#
# Epoch 31 TrainLoss: 0.0028 TrainAcc: 1.0000
# Epoch 31 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 32 TrainLoss: 0.0023 TrainAcc: 1.0000
# Epoch 32 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 33 TrainLoss: 0.0038 TrainAcc: 1.0000
# Epoch 33 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 34 TrainLoss: 0.0030 TrainAcc: 1.0000
# Epoch 34 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 35 TrainLoss: 0.0029 TrainAcc: 1.0000
# Epoch 35 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 36 TrainLoss: 0.0033 TrainAcc: 1.0000
# Epoch 36 ValLoss: 0.0007 ValAcc: 1.0000
#
# Epoch 37 TrainLoss: 0.0029 TrainAcc: 1.0000
# Epoch 37 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 38 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 38 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 39 TrainLoss: 0.0023 TrainAcc: 1.0000
# Epoch 39 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 40 TrainLoss: 0.0024 TrainAcc: 1.0000
# Epoch 40 ValLoss: 0.0003 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\40\model_weights20240513_1528.pth
#
# Epoch 41 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 41 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 42 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 42 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 43 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 43 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 44 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 44 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 45 TrainLoss: 0.0053 TrainAcc: 1.0000
# Epoch 45 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 46 TrainLoss: 0.0016 TrainAcc: 1.0000
# Epoch 46 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 47 TrainLoss: 0.0020 TrainAcc: 1.0000
# Epoch 47 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 48 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 48 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 49 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 49 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 50 TrainLoss: 0.0015 TrainAcc: 1.0000
# Epoch 50 ValLoss: 0.0002 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\50\model_weights20240513_1528.pth
#
# Epoch 51 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 51 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 52 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 52 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 53 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 53 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 54 TrainLoss: 0.0015 TrainAcc: 1.0000
# Epoch 54 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 55 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 55 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 56 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 56 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 57 TrainLoss: 0.0022 TrainAcc: 1.0000
# Epoch 57 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 58 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 58 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 59 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 59 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 60 TrainLoss: 0.0022 TrainAcc: 1.0000
# Epoch 60 ValLoss: 0.0001 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\60\model_weights20240513_1528.pth
#
# Epoch 61 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 61 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 62 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 62 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 63 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 63 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 64 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 64 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 65 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 65 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 66 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 66 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 67 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 67 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 68 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 68 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 69 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 69 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 70 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 70 ValLoss: 0.0001 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\70\model_weights20240513_1528.pth
#
# Epoch 71 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 71 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 72 TrainLoss: 0.0016 TrainAcc: 1.0000
# Epoch 72 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 73 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 73 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 74 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 74 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 75 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 75 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 76 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 76 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 77 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 77 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 78 TrainLoss: 0.0004 TrainAcc: 1.0000
# Epoch 78 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 79 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 79 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 80 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 80 ValLoss: 0.0000 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\80\model_weights20240513_1528.pth
#
# Epoch 81 TrainLoss: 0.0011 TrainAcc: 1.0000
# Epoch 81 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 82 TrainLoss: 0.0015 TrainAcc: 1.0000
# Epoch 82 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 83 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 83 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 84 TrainLoss: 0.0127 TrainAcc: 1.0000
# Epoch 84 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 85 TrainLoss: 0.0016 TrainAcc: 1.0000
# Epoch 85 ValLoss: 0.0009 ValAcc: 1.0000
#
# Epoch 86 TrainLoss: 0.0016 TrainAcc: 1.0000
# Epoch 86 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 87 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 87 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 88 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 88 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 89 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 89 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 90 TrainLoss: 0.0005 TrainAcc: 1.0000
# Epoch 90 ValLoss: 0.0001 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\90\model_weights20240513_1528.pth
#
# Epoch 91 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 91 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 92 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 92 ValLoss: 0.0000 ValAcc: 1.0000
#
# Epoch 93 TrainLoss: 0.0008 TrainAcc: 1.0000
# Epoch 93 ValLoss: 0.0000 ValAcc: 1.0000
#
# Epoch 94 TrainLoss: 0.0003 TrainAcc: 1.0000
# Epoch 94 ValLoss: 0.0000 ValAcc: 1.0000
#
# Epoch 95 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 95 ValLoss: 0.0000 ValAcc: 1.0000
#
# Epoch 96 TrainLoss: 0.0813 TrainAcc: 0.9733
# Epoch 96 ValLoss: 1.8965 ValAcc: 0.3867
#
# Epoch 97 TrainLoss: 0.0423 TrainAcc: 0.9867
# Epoch 97 ValLoss: 0.2554 ValAcc: 0.9467
#
# Epoch 98 TrainLoss: 0.0072 TrainAcc: 1.0000
# Epoch 98 ValLoss: 0.0113 ValAcc: 1.0000
#
# Epoch 99 TrainLoss: 0.0051 TrainAcc: 1.0000
# Epoch 99 ValLoss: 0.0017 ValAcc: 1.0000
#
# Epoch 100 TrainLoss: 0.0044 TrainAcc: 1.0000
# Epoch 100 ValLoss: 0.0009 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\100\model_weights20240513_1528.pth
#
# Epoch 101 TrainLoss: 0.0018 TrainAcc: 1.0000
# Epoch 101 ValLoss: 0.0010 ValAcc: 1.0000
#
# Epoch 102 TrainLoss: 0.0018 TrainAcc: 1.0000
# Epoch 102 ValLoss: 0.0008 ValAcc: 1.0000
#
# Epoch 103 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 103 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 104 TrainLoss: 0.0022 TrainAcc: 1.0000
# Epoch 104 ValLoss: 0.0007 ValAcc: 1.0000
#
# Epoch 105 TrainLoss: 0.0018 TrainAcc: 1.0000
# Epoch 105 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 106 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 106 ValLoss: 0.0010 ValAcc: 1.0000
#
# Epoch 107 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 107 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 108 TrainLoss: 0.0032 TrainAcc: 1.0000
# Epoch 108 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 109 TrainLoss: 0.0020 TrainAcc: 1.0000
# Epoch 109 ValLoss: 0.0006 ValAcc: 1.0000
#
# Epoch 110 TrainLoss: 0.0014 TrainAcc: 1.0000
# Epoch 110 ValLoss: 0.0002 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\110\model_weights20240513_1528.pth
#
# Epoch 111 TrainLoss: 0.0013 TrainAcc: 1.0000
# Epoch 111 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 112 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 112 ValLoss: 0.0004 ValAcc: 1.0000
#
# Epoch 113 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 113 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 114 TrainLoss: 0.0045 TrainAcc: 1.0000
# Epoch 114 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 115 TrainLoss: 0.0010 TrainAcc: 1.0000
# Epoch 115 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 116 TrainLoss: 0.0007 TrainAcc: 1.0000
# Epoch 116 ValLoss: 0.0002 ValAcc: 1.0000
#
# Epoch 117 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 117 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 118 TrainLoss: 0.0012 TrainAcc: 1.0000
# Epoch 118 ValLoss: 0.0003 ValAcc: 1.0000
#
# Epoch 119 TrainLoss: 0.0009 TrainAcc: 1.0000
# Epoch 119 ValLoss: 0.0001 ValAcc: 1.0000
#
# Epoch 120 TrainLoss: 0.0006 TrainAcc: 1.0000
# Epoch 120 ValLoss: 0.0001 ValAcc: 1.0000
# Saving Model...
# Model saved in TrainedWeights\120\model_weights20240513_1528.pth
#
# CSVs saved in TrainHistory\20240513_1528
# Training Finished!!!
